# %% [markdown]
# <a href="https://colab.research.google.com/github/malh718/datasci_1_loading/blob/main/HHA507HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HHA 507 HW 1

# %% [markdown]
# ## HIV related CSV file examples

# %%
import pandas as pd

# %%
HIVny = pd.read_csv('HIVNY.csv')

# %%
HIVny
# Out:
#       Year        Borough          UHF       Gender      Age  \
# 0     2011            All          All          All      All
# 1     2011            All          All         Male      All
# 2     2011            All          All       Female      All
# 3     2011            All          All  Transgender      All
# 4     2011            All          All       Female  13 - 19
# ...    ...            ...          ...          ...      ...
# 6000  2015  Staten Island  Willowbrook         Male      All
# 6001  2015  Staten Island  Willowbrook         Male      All
# 6002  2015  Staten Island  Willowbrook         Male      All
# 6003  2015  Staten Island  Willowbrook         Male      All
# 6004  2015  Staten Island  Willowbrook         Male      All
#
#                         Race  HIV diagnoses  HIV diagnosis rate  \
# 0                        All           3379                48.3
# 1                        All           2595                79.1
# ...

# %%
HIVny.head(10)
# Out:
#    Year Borough  UHF       Gender      Age Race  HIV diagnoses  \
# 0  2011     All  All          All      All  All           3379
# 1  2011     All  All         Male      All  All           2595
# 2  2011     All  All       Female      All  All            733
# 3  2011     All  All  Transgender      All  All             51
# 4  2011     All  All       Female  13 - 19  All             47
# 5  2011     All  All       Female  20 - 29  All            178
# 6  2011     All  All       Female  30 - 39  All            176
# 7  2011     All  All       Female  40 - 49  All            195
# 8  2011     All  All       Female  50 - 59  All            130
# 9  2011     All  All       Female      60+  All             57
#
#    HIV diagnosis rate  Concurrent diagnoses  % linked to care within 3 months  \
# 0                48.3                   640                                66
# 1                79.1                   480                                66
# ...

# %%
HIVny.columns
# Out:
# Index(['Year', 'Borough', 'UHF', 'Gender', 'Age', 'Race', 'HIV diagnoses',
#        'HIV diagnosis rate', 'Concurrent diagnoses',
#        '% linked to care within 3 months', 'AIDS diagnoses',
#        'AIDS diagnosis rate', 'PLWDHI prevalence', '% viral suppression',
#        'Deaths', 'Death rate', 'HIV-related death rate',
#        'Non-HIV-related death rate'],
#       dtype='object')

# %% [markdown]
# This dataset is related to HIV in New York. The columns are broken into Year, Borough, Gender, Age, Race, HIV diagnosis and more.

# %%
HIVincidence = pd.read_csv('HIVIncidence Rate2009-2021.csv')

# %%
HIVincidence.head(10)
# Out:
#        Jurisdiction  Value                      Race/ ethnicity  Year  \
# 0          Caroline    NaN                                Asian  2017
# 1             State   20.4  All races/ ethnicities (aggregated)  2017
# 2          Allegany    6.4  All races/ ethnicities (aggregated)  2017
# 3      Anne Arundel    8.7  All races/ ethnicities (aggregated)  2017
# 4    Baltimore City   44.7  All races/ ethnicities (aggregated)  2017
# 5  Baltimore County   15.9  All races/ ethnicities (aggregated)  2017
# 6           Calvert    6.5  All races/ ethnicities (aggregated)  2017
# 7          Caroline    3.6  All races/ ethnicities (aggregated)  2017
# 8           Carroll    5.6  All races/ ethnicities (aggregated)  2017
# 9             Cecil    5.8  All races/ ethnicities (aggregated)  2017
#
#          Measure
# 0  HIV Incidence
# 1  HIV Incidence
# 2  HIV Incidence
# 3  HIV Incidence
# 4  HIV Incidence
# 5  HIV Incidence
# 6  HIV Incidence
# 7  HIV Incidence
# 8  HIV Incidence
# ...

# %%
HIVincidence

# %%
HIVincidence.columns
# Out:
# Index(['Jurisdiction', 'Value', 'Race/ ethnicity', 'Year', 'Measure'], dtype='object')

# %% [markdown]
# This information was obstained from Maryland and shows specific cities and information in the colomns. Column information includes race, year and value.

# %%
STItest = pd.read_csv('STItest.csv')

# %%
STItest.head(10)
# Out:
#    Fiscal Years (FY)              STI Test Type  Number of STI Tests Provided  \
# 0               2003                   Chlamydia                      958,622
# 1               2003             Genital Herpes                         4,965
# 2               2003                  Gonorrhea                       977,345
# 3               2003                        HIV                       404,956
# 4               2003  Human Papillomavirus (HPV)                       25,453
# 5               2003                      Other                         6,236
# 6               2003                   Syphilis                       387,412
# 7               2004                   Chlamydia                      978,408
# 8               2004             Genital Herpes                         7,519
# 9               2004                  Gonorrhea                       969,806
#
#   Percentage of STI Tests Provided  Annotation Code  Annotation Description
# ...

# %%
STItest.columns
# Out:
# Index(['Fiscal Years (FY)', 'STI Test Type ', 'Number of STI Tests Provided',
#        'Percentage of STI Tests Provided', 'Annotation Code',
#        'Annotation Description'],
#       dtype='object')

# %% [markdown]
# This dataset is related to a program called Family PACT that has to do with STI testing. Colomns show the year, the test type and more information about the tests.

# %% [markdown]
# ## Diabetes related XLSX file examples

# %%
import pandas as pd

# %%
diaindia = pd.read_excel('Diabetes.xlsx')

# %%
diaindia.head(10)
# Out:
#                   States/UTs   Area  Number of Households surveyed  \
# 0                      India  Urban                         160138
# 1                      India  Rural                         476561
# 2                      India  Total                         636699
# 3  Andaman & Nicobar Islands  Urban                            527
# 4  Andaman & Nicobar Islands  Rural                           2097
# 5  Andaman & Nicobar Islands  Total                           2624
# 6             Andhra Pradesh  Urban                           3192
# 7             Andhra Pradesh  Rural                           8154
# 8             Andhra Pradesh  Total                          11346
# 9          Arunachal Pradesh  Urban                           3714
#
#    Number of Women age 15-49 years interviewed  \
# 0                                       179535
# 1                                       544580
# 2                                       724115
# ...

# %%
diaindia.columns
# Out:
# Index(['States/UTs', 'Area', 'Number of Households surveyed',
#        'Number of Women age 15-49 years interviewed',
#        'Number of Men age 15-54 years interviewed',
#        'Men age 15-49 years who are anaemic (<13.0 g/dl)22 (%)',
#        'Men age 15-19 years who are anaemic (<13.0 g/dl)22 (%)',
#        'Women  age 15 years and above with high (141-160 mg/dl) Blood sugar level23 (%)',
#        'Women age 15 years and above wih very high (>160 mg/dl) Blood sugar level23 (%)',
#        'Women age 15 years and above wih high or very high (>140 mg/dl) Blood sugar level or taking medicine to control blood sugar level23 (%)',
#        'Men age 15 years and above wih high (141-160 mg/dl) Blood sugar level23 (%)',
#        'Men (age 15 years and above wih  very high (>160 mg/dl) Blood sugar level23 (%)',
#        'Men age 15 years and above wih high or very high (>140 mg/dl) Blood sugar level  or taking medicine to control blood sugar level23 (%)'],
#       dtype='object')

# %% [markdown]
# This dataset is related to men and woman in India who have diabetes. The columns refer to characteristics of participants and their specific de-identified data.

# %%
gestationaldiabetes = pd.read_excel('Gestdia.xlsx')

# %%
gestationaldiabetes.head(10)
# Out:
#    Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  BMI  \
# 0            1   22                2                                1  NaN
# 1            2   26                2                                1  NaN
# 2            3   29                1                                0  NaN
# 3            4   28                2                                1  NaN
# 4            5   21                2                                1  NaN
# 5            6   29                2                                1  NaN
# 6            7   26                2                                1  NaN
# 7            8   27                1                                0  NaN
# 8            9   26                1                                0  NaN
# 9           10   21                2                                1  NaN
#
#     HDL  Family History  unexplained prenetal loss  \
# 0  55.0               0                          0
# ...

# %%
gestationaldiabetes.columns
# Out:
# Index(['Case Number', 'Age', 'No of Pregnancy',
#        'Gestation in previous Pregnancy', 'BMI', 'HDL', 'Family History',
#        'unexplained prenetal loss', 'Large Child or Birth Default', 'PCOS',
#        'Sys BP', 'Dia BP', 'OGTT', 'Hemoglobin', 'Sedentary Lifestyle',
#        'Prediabetes', 'Class Label(GDM /Non GDM)'],
#       dtype='object')

# %% [markdown]
# This dataset refers to a number of cases where pregnancies had gestational diabetes as well as other information such as hemoglobin and lifestyle choices.

# %%
diabetespregstats = pd.read_excel('diapregstats.xlsx')

# %%
diabetespregstats.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
diabetespregstats.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# This dataset has to do with gestational diabetes. The colomns contain information about a case such as insulin,bmi and more.

# %% [markdown]
# ## Cancer and COVID related JSON file examples

# %%
import pandas as pd

# %%
cervcanc = pd.read_json('cerv_cancer.json')

# %%
cervcanc.head(10)
# Out:
#    Age Number of sexual partners First sexual intercourse Num of pregnancies  \
# 0   18                         4                       15                  1
# 1   15                         1                       14                  1
# 2   34                         1                        ?                  1
# 3   52                         5                       16                  4
# 4   46                         3                       21                  4
# 5   42                         3                       23                  2
# 6   51                         3                       17                  6
# 7   26                         1                       26                  3
# 8   45                         1                       20                  5
# 9   44                         3                       15                  ?
#
#   Smokes Smokes (years)     Smokes (packs Hormonal Contraceptives  \
# ...

# %%
cervcanc.columns
# Out:
# Index(['Age', 'Number of sexual partners', 'First sexual intercourse',
#        'Num of pregnancies', 'Smokes', 'Smokes (years)', 'Smokes (packs',
#        'Hormonal Contraceptives', 'Hormonal Contraceptives (years)', 'IUD',
#        'IUD (years)', 'STDs', 'STDs (number)', 'STDs:condylomatosis',
#        'STDs:cervical condylomatosis', 'STDs:vaginal condylomatosis',
#        'STDs:vulvo-perineal condylomatosis', 'STDs:syphilis',
#        'STDs:pelvic inflammatory disease', 'STDs:genital herpes',
#        'STDs:molluscum contagiosum', 'STDs:AIDS', 'STDs:HIV',
#        'STDs:Hepatitis B', 'STDs:HPV', 'STDs: Number of diagnosis',
#        'STDs: Time since first diagnosis', 'STDs: Time since last diagnosis',
#        'Dx:Cancer', 'Dx:CIN', 'Dx:HPV', 'Dx', 'Hinselmann', 'Schiller',
#        'Citology', 'Biopsy'],
#       dtype='object')

# %% [markdown]
# This dataset pertains to cervical cancer of specific patients. The colomns show information pertaining to age, sexual history and STD testing.

# %%
lungcancer = pd.read_json('lung_cancer.json')

# %%
lungcancer.head(10)
# Out:
#           Name  Member_ID Diagnosis  Age  Smokes Smokes (years)  \
# 0         Wick      91550         M   35       3              0
# 1  Constantine     915664         M   27      20              0
# 2     Anderson     915691         M   30       0              0
# 3       Telles     915940         M   28       0             37
# 4     Maradona   91594602         M   68       4              0
# 5      Ronaldo     916221         M   34       0              0
# 6          Tal     916799         M   58      15             34
# 7        Bates     916838         M   22      12              0
# 8       Kidman     917062         M   45       2              0
# 9      Milland     917080         M   52      18    1.266972909
#
#       Smokes (packs  AreaQ  Alkhol  family history  Result
# 0    {'year)': '0'}      5       4               0       1
# 1    {'year)': '0'}      2       5               0       1
# 2    {'year)': '0'}      5       2               0       0
# ...

# %%
lungcancer.columns
# Out:
# Index(['Name', 'Member_ID', 'Diagnosis', 'Age', 'Smokes', 'Smokes (years)',
#        'Smokes (packs', 'AreaQ', 'Alkhol', 'family history', 'Result'],
#       dtype='object')

# %% [markdown]
# This dataset contains information about lungcancer and smoking history. The colomns are related to smoking history such as years, family who have smoked etc.

# %%
coviddeath = pd.read_json('covid.json')

# %%
coviddeath.head(10)
# Out:
#                                  AFG    OWID_AFR         ALB         DZA  \
# continent                       Asia        None      Europe      Africa
# location                 Afghanistan      Africa     Albania     Algeria
# last_updated_date         2021-11-05  2021-11-05  2021-11-05  2021-11-05
# total_cases                 156392.0   8526645.0    187994.0    206995.0
# new_cases                       29.0      9597.0       631.0       117.0
# new_cases_smoothed              28.0    4754.429       522.0     103.571
# total_deaths                  7284.0    219201.0      2948.0      5939.0
# new_deaths                       0.0       236.0         4.0         3.0
# new_deaths_smoothed            2.143     173.429       5.571       3.714
# total_cases_per_million     3925.953     6208.03    65436.24    4639.414
#
#                                 AND         AGO            AIA  \
# continent                    Europe      Africa  North America
# ...

# %%
coviddeath.columns
# Out:
# Index(['AFG', 'OWID_AFR', 'ALB', 'DZA', 'AND', 'AGO', 'AIA', 'ATG', 'ARG',
#        'ARM',
#        ...
#        'UZB', 'VUT', 'VAT', 'VEN', 'VNM', 'WLF', 'OWID_WRL', 'YEM', 'ZMB',
#        'ZWE'],
#       dtype='object', length=225)

# %% [markdown]
# This dataset refers to covid deaths globally. Information present in this dataset includes location, date of new cases and mortality related information.
